# %%
import numpy as np

def objective_function(x):
    return -x**2+4*x-4

population_size=50
generations=100
mutation_rate=0.1

population=np.random.uniform(-10,10,size=population_size)

for generation in range(generations):
    fitness=objective_function(population)
    
    sorted_indices=np.argsort(fitness)[::-1]
    selected_population=population[sorted_indices[:population_size]]
    
    crossover_population=np.random.choice(selected_population,size=population_size)
    
    mutation_mask=np.random.rand(population_size) < mutation_rate
    mutation_population=np.random.uniform(-1,1,size=population_size)
    crossover_population[mutation_mask] += mutation_population[mutation_mask]
    
    population=crossover_population
    
best_individual_index=np.argmax(objective_function(population))
best_x=population[best_individual_index]

print(f"Optimal x : {best_x}")
print(f"Optimal f(x) : {objective_function(best_x)}")
# Out:
# Optimal x : -1.2122601920907867
# Optimal f(x) : -10.318615541691138

# %%
import numpy as np

def objective_function(x):
    return x**2

population_size=50
generations=100
mutation_rate=0.1

population=np.random.uniform(-10,10,size=population_size)

for generation in range(generations):
    fitness=objective_function(population)
    
    sorted_indices=np.argsort(fitness)[::-1]
    selected_population=population[sorted_indices[:population_size]]
    
    crossover_population=np.random.choice(selected_population,size=population_size)
    
    mutation_mask=np.random.rand(population_size) < mutation_rate
    mutation_population=np.random.uniform(-1,1,size=population_size)
    crossover_population[mutation_mask] += mutation_population[mutation_mask]
    
    population=crossover_population
    
    best_individual_index=np.argmax(objective_function(population))
    best_x=population[best_individual_index]
    print(f"Generation {generation + 1} : Best Individual - {best_x}, Fitness - {objective_function(best_x)}")

print(f"Optimal x : {best_x}")
print(f"Optimal f(x) : {objective_function(best_x)}")
# Out:
# Generation 1 : Best Individual - 9.722570703509078, Fitness - 94.528381084733
# Generation 2 : Best Individual - 9.67714297551727, Fitness - 93.64709616860326
# Generation 3 : Best Individual - 9.67714297551727, Fitness - 93.64709616860326
# Generation 4 : Best Individual - 9.67714297551727, Fitness - 93.64709616860326
# Generation 5 : Best Individual - 10.417403592226744, Fitness - 108.52229760333867
# Generation 6 : Best Individual - 10.417403592226744, Fitness - 108.52229760333867
# Generation 7 : Best Individual - 10.417403592226744, Fitness - 108.52229760333867
# Generation 8 : Best Individual - 10.417403592226744, Fitness - 108.52229760333867
# Generation 9 : Best Individual - 10.417403592226744, Fitness - 108.52229760333867
# Generation 10 : Best Individual - 10.417403592226744, Fitness - 108.52229760333867
# Generation 11 : Best Individual - 9.426330869712181, Fitness - 88.85571366528882
# Generation 12 : Best Individual - 9.426330869712181, Fitness - 88.85571366528882
# Generation 13 : Best Individual - 9.426330869712181, Fitness - 88.85571366528882
# Generation 14 : Best Individual - -8.385054741181785, Fitness - 70.30914301261512
# Generation 15 : Best Individual - -8.032997720016386, Fitness - 64.52905236978846
# Generation 16 : Best Individual - -7.8413414448965195, Fitness - 61.486635655451835
# Generation 17 : Best Individual - -7.8413414448965195, Fitness - 61.486635655451835
# Generation 18 : Best Individual - -7.8413414448965195, Fitness - 61.486635655451835
# Generation 19 : Best Individual - -8.087656428685225, Fitness - 65.41018650845345
# Generation 20 : Best Individual - -7.6938612664927675, Fitness - 59.19550118803769
# Generation 21 : Best Individual - -7.8195500942650815, Fitness - 61.14536367672105
# Generation 22 : Best Individual - -7.8195500942650815, Fitness - 61.14536367672105
# Generation 23 : Best Individual - -7.6938612664927675, Fitness - 59.19550118803769
# Generation 24 : Best Individual - -7.556086667791015, Fitness - 57.094445731169124
# Generation 25 : Best Individual - -7.556086667791015, Fitness - 57.094445731169124
# Generation 26 : Best Individual - -7.556086667791015, Fitness - 57.094445731169124
# Generation 27 : Best Individual - -7.556086667791015, Fitness - 57.094445731169124
# Generation 28 : Best Individual - -7.556086667791015, Fitness - 57.094445731169124
# Generation 29 : Best Individual - -7.556086667791015, Fitness - 57.094445731169124
# Generation 30 : Best Individual - -7.556086667791015, Fitness - 57.094445731169124
# Generation 31 : Best Individual - -7.556086667791015, Fitness - 57.094445731169124
# Generation 32 : Best Individual - -7.556086667791015, Fitness - 57.094445731169124
# Generation 33 : Best Individual - -7.556086667791015, Fitness - 57.094445731169124
# Generation 34 : Best Individual - -7.556086667791015, Fitness - 57.094445731169124
# Generation 35 : Best Individual - -7.442419238905099, Fitness - 55.38960412762476
# Generation 36 : Best Individual - -7.627948613513786, Fitness - 58.1856000504069
# Generation 37 : Best Individual - -7.627948613513786, Fitness - 58.1856000504069
# Generation 38 : Best Individual - -8.035249884952774, Fitness - 64.56524071363357
# Generation 39 : Best Individual - -8.035249884952774, Fitness - 64.56524071363357
# Generation 40 : Best Individual - -8.042487705649858, Fitness - 64.68160849552912
# Generation 41 : Best Individual - -8.335540990371248, Fitness - 69.48124360215928
# Generation 42 : Best Individual - -8.335540990371248, Fitness - 69.48124360215928
# Generation 43 : Best Individual - -8.526185244920013, Fitness - 72.69583483069174
# Generation 44 : Best Individual - -8.526185244920013, Fitness - 72.69583483069174
# Generation 45 : Best Individual - -8.767296840867697, Fitness - 76.8654938958887
# Generation 46 : Best Individual - -8.593858899809527, Fitness - 73.85441078983541
# Generation 47 : Best Individual - -9.028467581670819, Fitness - 81.51322687328093
# Generation 48 : Best Individual - -9.298350722010982, Fitness - 86.45932614952214
# Generation 49 : Best Individual - -9.589452637554508, Fitness - 91.95760188790112
# Generation 50 : Best Individual - -9.589452637554508, Fitness - 91.95760188790112
# Generation 51 : Best Individual - -9.177328536072329, Fitness - 84.22335905900748
# Generation 52 : Best Individual - -9.501332623980772, Fitness - 90.27532163152135
# Generation 53 : Best Individual - -9.081125610662973, Fitness - 82.46684235663895
# Generation 54 : Best Individual - -8.593858899809527, Fitness - 73.85441078983541
# Generation 55 : Best Individual - -8.593858899809527, Fitness - 73.85441078983541
# Generation 56 : Best Individual - -8.593858899809527, Fitness - 73.85441078983541
# Generation 57 : Best Individual - -8.593858899809527, Fitness - 73.85441078983541
# Generation 58 : Best Individual - -8.867022778248389, Fitness - 78.62409294997578
# Generation 59 : Best Individual - -8.867022778248389, Fitness - 78.62409294997578
# Generation 60 : Best Individual - -9.444502235769336, Fitness - 89.19862248145199
# Generation 61 : Best Individual - -10.376579955655378, Fitness - 107.67341157610898
# Generation 62 : Best Individual - -10.376579955655378, Fitness - 107.67341157610898
# Generation 63 : Best Individual - -10.376579955655378, Fitness - 107.67341157610898
# Generation 64 : Best Individual - -10.376579955655378, Fitness - 107.67341157610898
# Generation 65 : Best Individual - -10.376579955655378, Fitness - 107.67341157610898
# Generation 66 : Best Individual - -10.376579955655378, Fitness - 107.67341157610898
# Generation 67 : Best Individual - -9.238062117731085, Fitness - 85.34179169105813
# Generation 68 : Best Individual - -9.238062117731085, Fitness - 85.34179169105813
# Generation 69 : Best Individual - -9.238062117731085, Fitness - 85.34179169105813
# Generation 70 : Best Individual - -9.238062117731085, Fitness - 85.34179169105813
# Generation 71 : Best Individual - -9.238062117731085, Fitness - 85.34179169105813
# Generation 72 : Best Individual - -8.990615660621806, Fitness - 80.83116995701808
# Generation 73 : Best Individual - -8.264174260778622, Fitness - 68.29657621251589
# Generation 74 : Best Individual - -9.24574435296579, Fitness - 85.4837886403988
# Generation 75 : Best Individual - -9.24574435296579, Fitness - 85.4837886403988
# Generation 76 : Best Individual - -9.24574435296579, Fitness - 85.4837886403988
# Generation 77 : Best Individual - -8.73732325329143, Fitness - 76.34081763250714
# Generation 78 : Best Individual - -8.898124077095742, Fitness - 79.17661209139095
# Generation 79 : Best Individual - -8.665091258567346, Fitness - 75.08380651930023
# Generation 80 : Best Individual - -8.665091258567346, Fitness - 75.08380651930023
# Generation 81 : Best Individual - -9.158251124565782, Fitness - 83.8735636606104
# Generation 82 : Best Individual - -9.629839417675282, Fitness - 92.7338072102126
# Generation 83 : Best Individual - -9.629839417675282, Fitness - 92.7338072102126
# Generation 84 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 85 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 86 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 87 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 88 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 89 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 90 : Best Individual - -10.055552670961767, Fitness - 101.11413951848633
# Generation 91 : Best Individual - -10.055552670961767, Fitness - 101.11413951848633
# Generation 92 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 93 : Best Individual - -9.755530630818257, Fitness - 95.17037788883324
# Generation 94 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 95 : Best Individual - -10.475076398930389, Fitness - 109.72722556342845
# Generation 96 : Best Individual - -10.475076398930389, Fitness - 109.72722556342845
# Generation 97 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 98 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 99 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 100 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Optimal x : -9.48732513352892
# Optimal f(x) : 90.00933818928954

# %%
import random

population_size=10
chromosome_length=6
mutation_rate=0.1
target_chromosome="110110"

def generate_population(population_size,chromosome_length):
    return [''.join(random.choice('01') for _ in range(chromosome_length)) for _ in range(population_size)]

def fitness(chromosome):
    return sum(bit==target_bit for bit,target_bit in zip(chromosome,target_chromosome))

def crossover(parent1,parent2):
    crossover_point=np.random.randint(0,len(parent1) - 1)
    child1=parent1[:crossover_point] + parent2[crossover_point:]
    child2=parent2[:crossover_point] + parent1[crossover_point:]
    
    return child1,child2

def mutate(chromosome,mutation_rate):
    mutated_chromosome=''.join(bit if random.random() > mutation_rate else random.choice('01') for bit in chromosome)
    return mutated_chromosome

def select_parents(population):
    parents=random.choices(population,weights=[fitness(chromosome) for chromosome in population],k=2)
    return parents[0],parents[1]

def genetic_algorithm(population_size,chromosome_length,mutation_rate,generations):
    population=generate_population(population_size,chromosome_length)
    
    for generation in range(generations):
        fitness_score=[fitness(chromosome) for chromosome in population]
        new_population=[]
        
        for _ in range(population_size // 2):
            parent1,parent2=select_parents(population)
            child1,child2=crossover(parent1,parent2)
            child1=mutate(child1,mutation_rate)
            child2=mutate(child2,mutation_rate)
            new_population.extend([child1,child2])
            
        population=new_population
        best_chromosome=max(population,key=fitness)
        print(f"Generations {generation + 1} : Best chromosome - {best_chromosome}, Fitness - {fitness(best_chromosome)}")    
        if fitness(best_chromosome)==len(target_chromosome):
            print("Target chromosome reached !")
            break
            
if __name__=="__main__":
    genetic_algorithm(population_size,chromosome_length,mutation_rate,generations=50)
# Out:
# Generations 1 : Best chromosome - 110101, Fitness - 4
# Generations 2 : Best chromosome - 110100, Fitness - 5
# Generations 3 : Best chromosome - 110100, Fitness - 5
# Generations 4 : Best chromosome - 111100, Fitness - 4
# Generations 5 : Best chromosome - 110100, Fitness - 5
# Generations 6 : Best chromosome - 110100, Fitness - 5
# Generations 7 : Best chromosome - 100110, Fitness - 5
# Generations 8 : Best chromosome - 110110, Fitness - 6
# Target chromosome reached !

# %%
import numpy as np
import matplotlib.pyplot as plt

# Rest of your code...

# Initialize an empty list to store the best fitness values over generations
best_fitness_values = []

for generation in range(generations):
    fitness_values = objective_function(population)

    # Rest of your code...

    best_individual_index = np.argmax(objective_function(population))
    best_individual = population[best_individual_index]
    best_fitness = objective_function(best_individual)

    # Append the best fitness value to the list
    best_fitness_values.append(best_fitness)

    print(f"Generation {generation + 1} : Best Individual - {best_individual}, Fitness - {best_fitness}")
# Out:
# Generation 1 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 2 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 3 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 4 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 5 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 6 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 7 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 8 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 9 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 10 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 11 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 12 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 13 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 14 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 15 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 16 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 17 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 18 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 19 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 20 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 21 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 22 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 23 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 24 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 25 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 26 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 27 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 28 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 29 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 30 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 31 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 32 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 33 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 34 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 35 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 36 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 37 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 38 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 39 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 40 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 41 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 42 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 43 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 44 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 45 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 46 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 47 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 48 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 49 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 50 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 51 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 52 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 53 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 54 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 55 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 56 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 57 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 58 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 59 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 60 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 61 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 62 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 63 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 64 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 65 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 66 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 67 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 68 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 69 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 70 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 71 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 72 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 73 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 74 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 75 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 76 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 77 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 78 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 79 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 80 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 81 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 82 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 83 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 84 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 85 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 86 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 87 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 88 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 89 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 90 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 91 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 92 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 93 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 94 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 95 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 96 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 97 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 98 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 99 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954
# Generation 100 : Best Individual - -9.48732513352892, Fitness - 90.00933818928954

# %%
# Plotting the fitness values over generations
plt.plot(range(1, generations + 1), best_fitness_values, marker='o', linestyle='-', color='g')
plt.xlabel('Generation')
plt.ylabel('Best Fitness')
plt.title('Genetic Algorithm Progress')
plt.grid(True)
plt.show()

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl
import matplotlib.pyplot as plt

dirtiness=ctrl.Antecedent(np.arange(0,11,1),"dirtiness")
stain_type=ctrl.Antecedent(np.arange(0,11,1),"stain_type")
washing_time=ctrl.Consequent(np.arange(0,61,1),"washing_time")

dirtiness["low"]=fuzz.trimf(dirtiness.universe,[0,0,5])
dirtiness["medium"]=fuzz.trimf(dirtiness.universe,[0,5,10])
dirtiness["high"]=fuzz.trimf(dirtiness.universe,[5,10,10])

stain_type["low"]=fuzz.trimf(stain_type.universe,[0,0,5])
stain_type["medium"]=fuzz.trimf(stain_type.universe,[0,5,10])
stain_type["high"]=fuzz.trimf(stain_type.universe,[5,10,10])

washing_time["short"]=fuzz.trimf(washing_time.universe,[0,0,30])
washing_time["medium"]=fuzz.trimf(washing_time.universe,[0,30,60])
washing_time["long"]=fuzz.trimf(washing_time.universe,[30,60,60])

rule1=ctrl.Rule(dirtiness["low"] & stain_type["low"],washing_time["short"])
rule2=ctrl.Rule(dirtiness["medium"] & stain_type["medium"],washing_time["medium"])
rule3=ctrl.Rule(dirtiness["high"] & stain_type["high"],washing_time["long"])

rule4 = ctrl.Rule(dirtiness["low"] & stain_type["medium"], washing_time["medium"])
rule5 = ctrl.Rule(dirtiness["medium"] & stain_type["high"], washing_time["long"])

washing_ctrl=ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5])
washing_machine=ctrl.ControlSystemSimulation(washing_ctrl)

if __name__=="__main__":
    washing_machine.input["dirtiness"]=7
    washing_machine.input["stain_type"]=8
    
    washing_machine.compute()
    
    print("Washing Time : ",washing_machine.output["washing_time"])
    washing_time.view(sim=washing_machine)
    plt.legend(loc="upper right")
    plt.show()
# Out:
# Washing Time :  35.268292682926806

# %%
import numpy as np

def max_min_composition(R,S):
    result=np.zeros((R.shape[0],S.shape[1]))
    
    for i in range(R.shape[0]):
        for j in range(S.shape[1]):
            max_min=0
            
            for k in range(R.shape[1]):
                max_min=max(max_min,min(R[i,k],S[k,j]))
            result[i,j]=max_min
    return result

R=np.array([[0.7,0.6],[0.8,0.3]])
S=np.array([[0.8,0.1,0.4],[0.5,0.6,0.7]])
result=max_min_composition(R,S)
print("Result of max-min composition :\n",result)
# Out:
# Result of max-min composition :
#  [[0.7 0.6 0.6]
#  [0.8 0.3 0.4]]

# %%
import numpy as np

def max_product_composition(R,S):
    result=np.zeros((R.shape[0],S.shape[1]))
    
    for i in range(R.shape[0]):
        for j in range(S.shape[1]):
            max_product=0
            
            for k in range(R.shape[1]):
                max_product=max(max_product,R[i,k] * S[k,j])
            result[i,j]=max_product
    return result

R=np.array([[0.7,0.6],[0.8,0.3]])
S=np.array([[0.8,0.1,0.4],[0.5,0.6,0.7]])
result=max_product_composition(R,S)
print("Result of max-product composition :\n",result)
# Out:
# Result of max-product composition :
#  [[0.56 0.36 0.42]
#  [0.64 0.18 0.32]]

# %%
z={}
def union(A,B):
    for x in A and B:
        z[x]=max(A[x],B[x])
    return z

def intersection(A,B):
    for x in A and B:
        z[x]=min(A[x],B[x])
    return z

def compliment(X):
    for x in X:
        z[x]=round((1 - X[x]),2)
    return z
def get_membership(key):
    while True:
        value=float(input("\nEnter the membership values (between 0 and 1) for "+key+" : "))
        if 0<= value <=1:
            return value
        else:
            print("\nINVALID INPUT!ENTER THE VALUE BETWEEN 0 AND 1!")
            
A={}
B={}
print("\nPROVING DE MORGAN'S LAW!")
n=int(input("Enter the number of elements : "))
for _ in range(n):
    key=input("\nEnter the crispy set element : ")
    value=get_membership(key)
    A[key]=value
    value=get_membership(key)
    B[key]=value

LHS=compliment(union(A,B))
RHS=intersection(compliment(A),compliment(B))

if LHS==RHS:
    print(f"\nLHS == RHS => {LHS} = {RHS}")
    print("\nDE MORGAN'S LAW HAS PROVED!")
# Out:
# PROVING DE MORGAN'S LAW!
# Enter the number of elements : 4
#
# Enter the crispy set element : a
#
# Enter the membership values (between 0 and 1) for a : 0.9
#
# Enter the membership values (between 0 and 1) for a : 0.3
#
# Enter the crispy set element : b
#
# Enter the membership values (between 0 and 1) for b : 0.2
#
# Enter the membership values (between 0 and 1) for b : 0.5
#
# Enter the crispy set element : c
#
# Enter the membership values (between 0 and 1) for c : 0.1
#
# Enter the membership values (between 0 and 1) for c : 0.5
#
# Enter the crispy set element : d
#
# Enter the membership values (between 0 and 1) for d : 0.9
#
# Enter the membership values (between 0 and 1) for d : 0.4
#
# LHS == RHS => {'a': 0.7, 'b': 0.5, 'c': 0.5, 'd': 0.6} = {'a': 0.7, 'b': 0.5, 'c': 0.5, 'd': 0.6}
#
# DE MORGAN'S LAW HAS PROVED!

# %%
z={}
def union(A,B):
    for x in A and B:
        z[x]=max(A[x],B[x])
    return z

def intersection(A,B):
    for x in A and B:
        z[x]=min(A[x],B[x])
    return z

def compliment(X):
    for x in X:
        z[x]=round((1 - X[x]),2)
    return z
def get_membership(key):
    while True:
        value=float(input("\nEnter the membership values (between 0 and 1) for "+key+" : "))
        if 0<= value <=1:
            return value
        else:
            print("\nINVALID INPUT!ENTER THE VALUE BETWEEN 0 AND 1!")
            
A={}
B={}
print("\nPROVING DE MORGAN'S SECOND LAW!")
n=int(input("Enter the number of elements : "))
for _ in range(n):
    key=input("\nEnter the crispy set element : ")
    value=get_membership(key)
    A[key]=value
    value=get_membership(key)
    B[key]=value

LHS=compliment(intersection(A,B))
RHS=union(compliment(A),compliment(B))

if LHS==RHS:
    print(f"\nLHS == RHS => {LHS} = {RHS}")
    print("\nDE MORGAN'S SECOND LAW HAS PROVED!")
# Out:
# PROVING DE MORGAN'S SECOND LAW!
# Enter the number of elements : 3
#
# Enter the crispy set element : a
#
# Enter the membership values (between 0 and 1) for a : 0.3
#
# Enter the membership values (between 0 and 1) for a : 0.7
#
# Enter the crispy set element : b
#
# Enter the membership values (between 0 and 1) for b : 0.5
#
# Enter the membership values (between 0 and 1) for b : 0.9
#
# Enter the crispy set element : c
#
# Enter the membership values (between 0 and 1) for c : 0.1
#
# Enter the membership values (between 0 and 1) for c : 0.5
#
# LHS == RHS => {'a': 0.3, 'b': 0.1, 'c': 0.5} = {'a': 0.3, 'b': 0.1, 'c': 0.5}
#
# DE MORGAN'S SECOND LAW HAS PROVED!

# %%
z={}
def union(A,B):
    for x in A and B:
        z[x]=max(A[x],B[x])
    return z

def intersection(A,B):
    for x in A and B:
        z[x]=min(A[x],B[x])
    return z

def compliment(X):
    for x in X:
        z[x]=round((1 - X[x]),2)
    return z
def get_membership(key):
    while True:
        value=float(input("\nEnter the membership values (between 0 and 1) for "+key+" : "))
        if 0<= value <=1:
            return value
        else:
            print("\nINVALID INPUT!ENTER THE VALUE BETWEEN 0 AND 1!")
            
A={}
B={}
print("\nPROVING DE MORGAN'S LAW!")
n=int(input("\nEnter the number of elements : "))
for _ in range(n):
    key=input("\nEnter the crispy set element : ")
    value=get_membership(key)
    A[key]=value
    value=get_membership(key)
    B[key]=value
print(f"\n{A} UNION {B} =>\t{union(A,B)}")
print(f"\n{A} INTERSECTION {B} =>\t{intersection(A,B)}")
print(f"\nCOMPLIMENT OF {A} =>\t{compliment(A)}")
print(f"\nCOMPLIMENT OF {B} =>\t{compliment(B)}")
# Out:
# PROVING DE MORGAN'S LAW!
#
# Enter the number of elements : 3
#
# Enter the crispy set element : a
#
# Enter the membership values (between 0 and 1) for a : 0.8
#
# Enter the membership values (between 0 and 1) for a : 0.2
#
# Enter the crispy set element : b
#
# Enter the membership values (between 0 and 1) for b : 0.5
#
# Enter the membership values (between 0 and 1) for b : 0.7
#
# Enter the crispy set element : c
#
# Enter the membership values (between 0 and 1) for c : 0.3
#
# Enter the membership values (between 0 and 1) for c : 0.2
#
# {'a': 0.8, 'b': 0.5, 'c': 0.3} UNION {'a': 0.2, 'b': 0.7, 'c': 0.2} =>	{'a': 0.8, 'b': 0.7, 'c': 0.3}
#
# {'a': 0.8, 'b': 0.5, 'c': 0.3} INTERSECTION {'a': 0.2, 'b': 0.7, 'c': 0.2} =>	{'a': 0.2, 'b': 0.5, 'c': 0.2}
#
# COMPLIMENT OF {'a': 0.8, 'b': 0.5, 'c': 0.3} =>	{'a': 0.2, 'b': 0.5, 'c': 0.7}
#
# COMPLIMENT OF {'a': 0.2, 'b': 0.7, 'c': 0.2} =>	{'a': 0.8, 'b': 0.3, 'c': 0.8}

# %%
import numpy as np

class simpleperceptron:
    def __init__(self,input_size,hidden_size,output_size):
        self.weights_input_hidden=np.random.rand(input_size,hidden_size)
        self.bias_hidden=np.zeros((1,hidden_size))
        self.weights_hidden_output=np.random.rand(hidden_size,output_size)
        self.bias_output=np.zeros((1,output_size))
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    def sigmoid_derivative(self,x):
        return x * (1 - x)
    
    def forward(self,inputs):
        self.hidden_layer_activation=self.sigmoid(np.dot(inputs,self.weights_input_hidden) + self.bias_hidden)
        self.output_layer_activation=self.sigmoid(np.dot(self.hidden_layer_activation,self.weights_hidden_output) + self.bias_output)
        
        return self.output_layer_activation
    
    def backward(self,inputs,targets,learning_rate):
        output_layer_error=targets - self.output_layer_activation
        output_layer_delta=output_layer_error * self.sigmoid_derivative(self.output_layer_activation)
        hidden_layer_error=output_layer_delta.dot(self.weights_hidden_output.T)
        hidden_layer_delta=hidden_layer_error * self.sigmoid_derivative(self.hidden_layer_activation)
        
        self.weights_hidden_output += self.hidden_layer_activation.T.dot(output_layer_delta)*learning_rate
        self.bias_output += np.sum(output_layer_delta, axis=0,keepdims=True)*learning_rate
        self.weights_input_hidden += inputs.T.dot(hidden_layer_delta)*learning_rate
        self.bias_hidden += np.sum(hidden_layer_delta, axis=0, keepdims=True)*learning_rate
        
    def train(self,inputs,targets,epochs,learning_rate):
        for epoch in range(epochs):
            for i in range(len(inputs)):
                input_data=np.array([inputs[i]])
                target_data=np.array(targets[i])
                output=self.forward(input_data)
                self.backward(input_data,target_data,learning_rate)
                
            if epoch %100 ==0:
                mse=np.mean(np.square(targets - self.forward(inputs)))
                print(f"Epoch {epoch} , Mean Squarred Error {mse}")
                
if __name__=="__main__":
    inputs=np.array([[0,0],[0,1],[1,0],[1,1]])
    targets=np.array([[0],[1],[1],[0]])
    model=simpleperceptron(input_size=2,hidden_size=4,output_size=1)
    model.train(inputs,targets,epochs=1000,learning_rate=0.1)
    test_input=np.array([[0,0],[0,1],[1,0],[1,1]])
    predictions=model.forward(test_input)
    print("Predictions :\n",predictions)
# Out:
# Epoch 0 , Mean Squarred Error 0.3481291755427988
# Epoch 100 , Mean Squarred Error 0.2491632121508951
# Epoch 200 , Mean Squarred Error 0.24890612661113795
# Epoch 300 , Mean Squarred Error 0.24860642468541866
# Epoch 400 , Mean Squarred Error 0.24825237641468745
# Epoch 500 , Mean Squarred Error 0.24782800889603998
# Epoch 600 , Mean Squarred Error 0.24731420957690647
# Epoch 700 , Mean Squarred Error 0.24668839534982123
# Epoch 800 , Mean Squarred Error 0.24592445749938036
# Epoch 900 , Mean Squarred Error 0.2449931273526233
# Predictions :
#  [[0.45137542]
#  [0.5187778 ]
#  [0.50568932]
#  [0.54391486]]

# %%
from tensorflow.keras import models,layers

def create_mlp(input_size,hidden_size,output_size):
    model=models.Sequential()
    model.add(layers.InputLayer(input_shape=(input_size,)))
    
    for hidden_size in hidden_sizes:
        model.add(layers.Dense(hidden_size,activation="relu"))
        
    model.add(layers.Dense(output_size,activation="softmax"))
    return model

if __name__=="__main__":
    input_size=10
    hidden_sizes=[64,32]
    output_size=2
    mlp_model=create_mlp(input_size,hidden_size,output_size)
    mlp_model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 64)                704
#
#  dense_9 (Dense)             (None, 32)                2080
#
#  dense_10 (Dense)            (None, 2)                 66
#
# =================================================================
# Total params: 2850 (11.13 KB)
# Trainable params: 2850 (11.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras import models,layers

def create_mlp(input_size,hidden_size,output_size):
    model=models.Sequential()
    model.add(layers.InputLayer(input_shape=(input_size,)))
    
    model.add(layers.Dense(hidden_sizes[0],activation="relu"))
    model.add(layers.Dense(hidden_sizes[1],activation="tanh"))
        
    model.add(layers.Dense(output_size,activation="softmax"))
    return model

if __name__=="__main__":
    input_size=10
    hidden_sizes=[64,32]
    output_size=2
    mlp_model=create_mlp(input_size,hidden_size,output_size)
    mlp_model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_11 (Dense)            (None, 64)                704
#
#  dense_12 (Dense)            (None, 32)                2080
#
#  dense_13 (Dense)            (None, 2)                 66
#
# =================================================================
# Total params: 2850 (11.13 KB)
# Trainable params: 2850 (11.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras import models, layers
from tensorflow.keras import backend as K

#def swish(x):
 #   return x * K.sigmoid(x)

def create_mlp(input_size, hidden_sizes, output_size):
    model = models.Sequential()
    model.add(layers.InputLayer(input_shape=(input_size,)))

    for hidden_size in hidden_sizes:
        model.add(layers.Dense(hidden_size, activation="swish"))

    model.add(layers.Dense(output_size, activation="softmax"))
    return model

if __name__ == "__main__":
    input_size = 10
    hidden_sizes = [64, 32]
    output_size = 2

    mlp_model = create_mlp(input_size, hidden_sizes, output_size)
    mlp_model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_29 (Dense)            (None, 64)                704
#
#  dense_30 (Dense)            (None, 32)                2080
#
#  dense_31 (Dense)            (None, 2)                 66
#
# =================================================================
# Total params: 2850 (11.13 KB)
# Trainable params: 2850 (11.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import numpy as np

class simpleperceptron:
    def __init__(self, input_size, hidden_size, output_size):
        self.weights_input_hidden = np.random.rand(input_size, hidden_size)
        self.bias_hidden = np.zeros((1, hidden_size))
        self.weights_hidden_output = np.random.rand(hidden_size, output_size)
        self.bias_output = np.zeros((1, output_size))

    def tanh(self, x):
        return np.tanh(x)

    def tanh_derivative(self, x):
        return 1.0 - np.tanh(x)**2

    def forward(self, inputs):
        self.hidden_layer_activation = self.tanh(np.dot(inputs, self.weights_input_hidden) + self.bias_hidden)
        self.output_layer_activation = self.tanh(np.dot(self.hidden_layer_activation, self.weights_hidden_output) + self.bias_output)

        return self.output_layer_activation

    def backward(self, inputs, targets, learning_rate):
        output_layer_error = targets - self.output_layer_activation
        output_layer_delta = output_layer_error * self.tanh_derivative(self.output_layer_activation)
        hidden_layer_error = output_layer_delta.dot(self.weights_hidden_output.T)
        hidden_layer_delta = hidden_layer_error * self.tanh_derivative(self.hidden_layer_activation)

        self.weights_hidden_output += self.hidden_layer_activation.T.dot(output_layer_delta) * learning_rate
        self.bias_output += np.sum(output_layer_delta, axis=0, keepdims=True) * learning_rate
        self.weights_input_hidden += inputs.T.dot(hidden_layer_delta) * learning_rate
        self.bias_hidden += np.sum(hidden_layer_delta, axis=0, keepdims=True) * learning_rate

    def train(self, inputs, targets, epochs, learning_rate):
        for epoch in range(epochs):
            for i in range(len(inputs)):
                input_data = np.array([inputs[i]])
                target_data = np.array(targets[i])
                output = self.forward(input_data)
                self.backward(input_data, target_data, learning_rate)

            if epoch % 100 == 0:
                mse = np.mean(np.square(targets - self.forward(inputs)))
                print(f"Epoch {epoch}, Mean Squared Error {mse}")

if __name__ == "__main__":
    inputs = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
    targets = np.array([[0], [1], [1], [0]])
    model = simpleperceptron(input_size=2, hidden_size=4, output_size=1)
    model.train(inputs, targets, epochs=1000, learning_rate=0.1)
    test_input = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
    predictions = model.forward(test_input)
    print("Predictions :\n", predictions)
# Out:
# Epoch 0, Mean Squared Error 0.23881476627184667
# Epoch 100, Mean Squared Error 0.19353751975127226
# Epoch 200, Mean Squared Error 0.12239427704482939
# Epoch 300, Mean Squared Error 0.016876932508042425
# Epoch 400, Mean Squared Error 0.0028575688458400803
# Epoch 500, Mean Squared Error 0.0009593519415735048
# Epoch 600, Mean Squared Error 0.00044751068907544826
# Epoch 700, Mean Squared Error 0.00025022696484516236
# Epoch 800, Mean Squared Error 0.0001566961624233678
# Epoch 900, Mean Squared Error 0.00010599034969571721
# Predictions :
#  [[ 0.00497847]
#  [ 0.98842228]
#  [ 0.98824586]
#  [-0.00267605]]

# %%
from tensorflow.keras import models, layers
from tensorflow.keras import backend as K

#def swish(x):
 #   return x * K.sigmoid(x)

def create_mlp(input_size, hidden_sizes, output_size):
    model = models.Sequential()
    model.add(layers.InputLayer(input_shape=(input_size,)))

    for hidden_size in hidden_sizes:
        model.add(layers.Dense(hidden_size, activation="swish"))

    model.add(layers.Dense(output_size, activation="softmax"))
    return model

if __name__ == "__main__":
    input_size = 10
    hidden_sizes = [64, 32]
    output_size = 2

    mlp_model = create_mlp(input_size, hidden_sizes, output_size)
    mlp_model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_32 (Dense)            (None, 64)                704
#
#  dense_33 (Dense)            (None, 32)                2080
#
#  dense_34 (Dense)            (None, 2)                 66
#
# =================================================================
# Total params: 2850 (11.13 KB)
# Trainable params: 2850 (11.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
